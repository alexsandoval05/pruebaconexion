# %%
import pandas as pd

df = pd.read_csv("/content/sprint7_webinar22_clinic_transactions.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   transaction_id        40000 non-null  object
#  1   customer_id           40000 non-null  object
#  2   appointment_date      40000 non-null  object
#  3   service_type          40000 non-null  object
#  4   appointment_channel   40000 non-null  object
#  5   payment_method        40000 non-null  object
#  6   amount_gross          40000 non-null  float64
#  7   discount_pct          40000 non-null  int64
#  8   amount_net            40000 non-null  float64
#  9   is_refund             40000 non-null  int64
#  10  refund_reason         972 non-null    object
#  11  wait_time_min         40000 non-null  float64
#  12  service_duration_min  40000 non-null  float64
#  13  satisfaction_score    36879 non-null  float64
#  14  signup_date           40000 non-null  object
#  15  age                   40000 non-null  int64
#  16  gender                40000 non-null  object
#  17  city                  40000 non-null  object
#  18  acquisition_channel   40000 non-null  object
#  19  plan                  40000 non-null  object
#  20  has_insurance         40000 non-null  int64
#  21  is_revenue            40000 non-null  int64
# dtypes: float64(5), int64(5), object(12)
# memory usage: 6.7+ MB

# %%
df.head()
# Out:
#   transaction_id customer_id appointment_date      service_type  \
# 0       T0032824      C04111       2024-04-02      Especialista
# 1       T0016299      C02038       2023-03-20      Especialista
# 2       T0028506      C03569       2025-09-28  Consulta general
# 3       T0006690      C00832       2025-03-06       Odontología
# 4       T0026894      C03371       2025-12-20  Consulta general
#
#   appointment_channel payment_method  amount_gross  discount_pct  amount_net  \
# 0                 Web        Tarjeta       82231.0             5     78119.0
# 1                 Web        Tarjeta       79034.0             0     79034.0
# 2                 Web            PSE       52059.0            20     41647.0
# 3          Presencial            PSE      144422.0            20    115538.0
# 4         Call Center        Tarjeta       34207.0             0     34207.0
#
#    is_refund  ... service_duration_min  satisfaction_score  signup_date  age  \
# 0          0  ...            40.739359                10.0   2023-01-04   44
# 1          0  ...            31.515534                 9.0   2023-02-14   39
# 2          0  ...            38.464583                10.0   2025-04-07   26
# 3          0  ...            11.924011                 8.0   2023-09-21   18
# 4          0  ...            43.829601                 7.0   2025-12-17   39
#
#   gender         city acquisition_channel     plan has_insurance is_revenue
# 0      F       Bogotá               Email   Básico             0          1
# 1      M  Santa Marta             Organic   Básico             0          1
# 2      F       Bogotá               Email  Premium             0          1
# 3      F       Bogotá            Referral  Premium             0          1
# 4      M     Medellín             Organic   Básico             1          1
#
# [5 rows x 22 columns]

# %%
df['appointment_date'] = pd.to_datetime(df['appointment_date']), format=%Y-%m-%d"
# Out:
#   File "/tmp/ipython-input-2472611521.py", line 1
#     df['appointment_date'] = pd.to_datetime(df['appointment_date']), format=%Y-%m-%d
#     ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
def corregirVacios()

# %%
df.head()
# Out:
#   customer_id    country          city segment signup_date last_activity_date  \
# 0     C000001     México          CDMX  Retail  2024-08-23         2025-08-07
# 1     C000002  Argentina       Mendoza     SMB  2025-06-22         2025-12-26
# 2     C000003   Colombia      Medellín  Retail  2024-09-02         2024-12-02
# 3     C000004   Colombia  Barranquilla     SMB  2025-11-01         2025-12-28
# 4     C000005   Colombia        Bogotá  Retail  2024-12-29         2025-09-20
#
#   device_os plan_type  monthly_fee_usd  orders_90d  avg_order_value_usd  \
# 0     macOS     Basic            30.76           4                24.42
# 1       iOS       Pro            65.80           6                26.20
# 2   Android      Plus            49.18           2                22.13
# 3     Linux     Basic            15.66           7                30.46
# 4   Windows      Plus              NaN           4                38.71
#
#    total_spend_90d_usd  support_tickets_90d  satisfaction_score coupon_used  \
# 0                97.69                    1                 4.0         yes
# 1               157.18                    2                 4.3         yes
# 2                44.25                    0                 4.2         yes
# 3               213.23                    0                 3.4          no
# 4               154.85                    0                 4.1         yes
#
#   preferred_category  churned   age monthly_fee_raw last_activity_raw
# 0               Moda        0  27.0           30.76        2025-08-07
# 1               Moda        0  26.0            65.8        2025-12-26
# 2          Alimentos        1  27.0           49.18        2024-12-02
# 3              Hogar        0  45.0           15.66        2025-12-28
# 4            Belleza        0  45.0             NaN        2025-09-20

# %%
df
